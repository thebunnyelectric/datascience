# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Niomi Hill**\
# Controller

# %% [markdown]
# I'm interested in data science because it helps me to recognize socioecoonomic patterns and anomalies.

# %% [markdown]
# ### The following Python code performs simple arithmetic.

# %%
18*2+1
# Out:
# 37

# %% [markdown]
# ### The following Jupyter markdown contains the following:
#
# 1. bulleted list
# 2. numbered list
# 3. table
# 4. hyperlink
# 5. image
#
# A list of problems to solve:
#
# - how can I escape northeast Canada as soon as humanely possible with the least amount of stress?
# - how do find a vocation that makes a decent amount of money but doesn't suck the ever living soul out of me?
# - how do I stay as young and bright and athletic for as long as possible and live for hundreds of years?
#
# A table of foods I eat most frequently:
#
# | Food |
# |:--------:|
# | Carrots |
# | Chicken |
# | Peas |
# | Sweet potatoes |
# | Wheat |
# | Strawberries |
# | Honey |
#
# This is Alba the glowing bunny:
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/b/b0/Green_rabbit.jpg">
#
# More information about glowing bunnies can be found here:
#
# __[Alba the glowing rabbit](https://en.wikipedia.org/wiki/Alba_%28rabbit%29)__
